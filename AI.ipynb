# %% [markdown]
# <a href="https://colab.research.google.com/github/Aschit/aschitdhakal1/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lamda expression

squares= lambda x:x**2
print(squares(9))
# Out:
# 81

# %%
squares= list(map(lambda x:x**2,[12,23,45,67,77,88,999]))
print(square)
square= list(map(square,[12,34,55,66,6,7,]))
print(square)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d82ff64e5da2> in <cell line: 2>()
#       1 squares= list(map(lambda x:x**2,[12,23,45,67,77,88,999]))
# ----> 2 print(square)
#       3 square= list(map(square,[12,34,55,66,6,7,]))
#       4 print(square)
#
# NameError: name 'square' is not defined

# %%
square
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15a5122b62de> in <cell line: 1>()
# ----> 1 square
#
# NameError: name 'square' is not defined

# %%
def even(x):
  if(x%2==0):
    return x

# %%
even= list(filter(even,[12,45,77,7,8,8,8,8,88]))
print(even)
# Out:
# [12, 8, 8, 8, 8, 88]

# %%
evens=list(filter(lambda x:x%2==0),[1,5,5,6,77,8,8,8,12])
print(evens)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-01b6525afd16> in <cell line: 1>()
# ----> 1 evens=list(filter(lambda x:x%2==0),[1,5,5,6,77,8,8,8,12])
#       2 print(evens)
#
# TypeError: filter expected 2 arguments, got 1

# %%
#slicing


x=[12,34,5,5,5,66,7,7,7,7]

# %%
x[:1]       #gives the first element
# Out:
# [12]

# %%
x[:5]
# Out:
# [12, 34, 5, 5, 5]

# %%
x[-1]                 #gives last element
# Out:
# 7

# %%
x[1:-1]        #gives all the element includig the alast elemwnrt
# Out:
# [34, 5, 5, 5, 66, 7, 7, 7]

# %%
x[1:-1]   #givea all the element excluding the first and last
# Out:
# [34, 5, 5, 5, 66, 7, 7, 7]

# %%
name='ram dhakal'

# %%
name[0:3]
# Out:
# 'ram'

# %%
name[4:9]
# Out:
# 'dhaka'

# %%
#string splitting

sen="Today is quite cloudly day. i wish i culd stay in home today"

# %%
splits= sen.split(".")

# %%
print(splits)
print(type(splits))
print(len(splits))
print(splits[0])
# Out:
# ['Today is quite cloudly day', ' i wish i culd stay in home today']
# <class 'list'>
# 2
# Today is quite cloudly day

# %%
for i in splits:
  print(i)
# Out:
# Today is quite cloudly day
#  i wish i culd stay in home today

# %%
wordSplit= sen.split('')
print('the total number of words:(len(wordsplit))')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-c1a2a53a99f8> in <cell line: 1>()
# ----> 1 wordSplit= sen.split('')
#       2 print('the total number of words:(len(wordsplit))')
#
# ValueError: empty separator

# %%
for i in wordsplit:
  print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9c37b116dbc6> in <cell line: 1>()
# ----> 1 for i in wordsplit:
#       2   print(i)
#
# NameError: name 'wordsplit' is not defined

# %%
 txt ="hello, its me aschit dahakak, i m 22 years old"
 x= txt.split(",")
 print(x)
# Out:
# ['hello', ' its me aschit dahakak', ' i m 22 years old']

# %%
txt = "hello, my name is Peter, I am 26 years old"

x = txt.split(", ")

print(x)
# Out:
# ['hello', 'my name is Peter', 'I am 26 years old']

# %%
#using hash tag for selector

txt= "#######bannaa#iuayagagagag#orange"
x= txt.split(",")
print(x)
# Out:
# ['#######bannaa#iuayagagagag#orange']

# %%
#split into two items

txt= "#aschit #dhakal #abibhd #qweert"

# setting the max paramter to 1 return the 2 dimension
x= txt.split("#,1")
print(x)
# Out:
# ['#aschit #dhakal #abibhd #qweert']

# %%
text='How to split in python'     #number of character see

print(len(text.split()))
print(text)
# Out:
# 5
# How to split in python

# %%
# import pandas

# %% [markdown]
# pandas is a python library used foer working with data xcell
# #has to be used for analyzing the clearing exploring and manipulating th data

# %%
import pandas as pd

# %%
data={'Name':['hari','ram','gopal'],
      'Designation':['Manager','Poem','Officer'],
      'Experience':[2,3,4],
      'salary':[34000,50000,80000]}

# %%
for i in data:
  print(i,'',data[i])
# Out:
# Name  ['hari', 'ram', 'gopal']
# Designation  ['Manager', 'Poem', 'Officer']
# Experience  [2, 3, 4]
# salary  [34000, 50000, 80000]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name Designation  Experience  salary
# 0   hari     Manager           2   34000
# 1    ram        Poem           3   50000
# 2  gopal     Officer           4   80000

# %%
df.describe()
# Out:
#        Experience        salary
# count         3.0      3.000000
# mean          3.0  54666.666667
# std           1.0  23352.373184
# min           2.0  34000.000000
# 25%           2.5  42000.000000
# 50%           3.0  50000.000000
# 75%           3.5  65000.000000
# max           4.0  80000.000000

# %%
df.shape
# Out:
# (3, 4)

# %%
#data dictionary


dataDict={'Name':['ram','shyam','hari','gopal','manish'],
'Age':[23,5,66,7,8],
'Designation':['clerk','supervisor','manager','Director','Superintendent'],
'Experience':[2,3,5,6,7],
'Salary':[10000,50000,90000,70000,40000]}

# %%
for i in dataDict:
  print(i,'',dataDict[i])
# Out:
# Name  ['ram', 'shyam', 'hari', 'gopal', 'manish']
# Age  [23, 5, 66, 7, 8]
# Designation  ['clerk', 'supervisor', 'manager', 'Director', 'Superintendent']
# Experience  [2, 3, 5, 6, 7]
# Salary  [10000, 50000, 90000, 70000, 40000]

# %%
import pandas as pd

# %%
df=pd.DataFrame(dataDict)

# %%
df
# Out:
#      Name  Age     Designation  Experience  Salary
# 0     ram   23           clerk           2   10000
# 1   shyam    5      supervisor           3   50000
# 2    hari   66         manager           5   90000
# 3   gopal    7        Director           6   70000
# 4  manish    8  Superintendent           7   40000

# %%
df.shape
# Out:
# (5, 5)

# %%
from numpy.random.mtrand import f
from pandas.core.indexes.base import F
print(f'Number of row:  {(df.shape[0])}')
print(f'Number of column : {(df.shape[1])}')
# Out:
# Number of row:  5
# Number of column : 5

# %%
df.describe()
# Out:
#             Age  Experience        Salary
# count   5.00000    5.000000      5.000000
# mean   21.80000    4.600000  52000.000000
# std    25.72353    2.073644  30331.501776
# min     5.00000    2.000000  10000.000000
# 25%     7.00000    3.000000  40000.000000
# 50%     8.00000    5.000000  50000.000000
# 75%    23.00000    6.000000  70000.000000
# max    66.00000    7.000000  90000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         5 non-null      object
#  1   Age          5 non-null      int64
#  2   Designation  5 non-null      object
#  3   Experience   5 non-null      int64
#  4   Salary       5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
pip install pandas-profiling as pp
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
df.head()
# Out:
#      Name  Age     Designation  Experience  Salary
# 0     ram   23           clerk           2   10000
# 1   shyam    5      supervisor           3   50000
# 2    hari   66         manager           5   90000
# 3   gopal    7        Director           6   70000
# 4  manish    8  Superintendent           7   40000

# %%
profile= pp.profileReport(df)
profile.t0_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-2f362a0bd079> in <cell line: 1>()
# ----> 1 profile= pp.profileReport(df)
#       2 profile.t0_file("output.html")
#       3
#       4
#
# NameError: name 'pp' is not defined

# %%
import pandas as pd

# %%
    pd.read_csv('Global.csv')
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4fcafb2513a4> in <cell line: 1>()
# ----> 1 Global.csv.shape()
#       2
#
# NameError: name 'Global' is not defined

# %%
  GlobalData=pd.read_csv('Global.csv')

# %%
GlobalData
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
GlobalData.shape
# Out:
# (3649, 21)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
GlobalData=pd.read_csv('drive/MyDrive/Global.csv')

# %%
GlobalData
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...
